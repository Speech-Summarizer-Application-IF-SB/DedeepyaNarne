# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/auido.wav"

# %%
import os
print(os.path.exists(file_path))
# Out:
# True

# %%
import wave

wf = wave.open(file_path, "rb")
print("Channels:", wf.getnchannels())
print("Sample rate:", wf.getframerate())
print("Duration (seconds):", wf.getnframes() / wf.getframerate())
# Out:
# Channels: 2
# Sample rate: 48000
# Duration (seconds): 3.584

# %%
# !apt-get install ffmpeg  # install ffmpeg if not installed
# !ffmpeg -i "/content/drive/MyDrive/auido.wav" -ac 1 -ar 16000 "/content/drive/MyDrive/auido_mono.wav"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
file_path = "/content/drive/MyDrive/auido_mono.wav"

# %%
wf = wave.open(file_path, "rb")
print("\nCleaned File Properties:")
print(" - Channels:", wf.getnchannels())
print(" - Sample rate:", wf.getframerate())
print(" - Duration (seconds):", round(wf.getnframes() / wf.getframerate(), 2))
wf.close()
# Out:
# Cleaned File Properties:
#  - Channels: 1
#  - Sample rate: 16000
#  - Duration (seconds): 3.58
